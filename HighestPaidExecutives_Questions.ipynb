# %% [markdown]
# # Pandas Practice Run

# %% [markdown]
# ##### Import Pandas as 'pd'

# %%
import pandas as pd

# %% [markdown]
# ##### Read in the excel file and save it to a variable (name it)

# %%
execs = pd.read_excel('Men v. Women list of highest-paid executives  copy.xlsx')

# %% [markdown]
# ##### Take a look at your dataset briefly - (1) Call the dataset, (2) use the head() method, (3) use the tail() method.

# %%
execs
# Out:
#          Names (Men)                   Company                  Title  \
# 0          Marc Lore                    Walmart  CEO, U.S. E-Commerce
# 1      Sundar Pichai                     Google                   CEO
# 2    Thomas Rutledge     Charter Communications                   CEO
# 3      John Weinberg                  Evercore     Executive Chairman
# 4     Leslie Moonves                       CBS                    CEO
# 5   Dean Metropoulos             Hostess Brands    Executive Chairman
# 6       John Bickham     Charter Communications                   COO
# 7   Lawrence Ellison                     Oracle                   CTO
# 8           Bob Iger                     Disney                   CEO
# 9          Mark Hurd                     Oracle                   CEO
# 10     Stephen Burke               NBCUniversal                   CEO
# 11      David Zaslav   Discovery Communications                   CEO
# 12     Thomas Kurian                     Oracle    President, Product
# 13      Andrew Jassy                     Amazon     CEO, Web Services
# 14    Jon Feltheimer  Lions Gate Entertainment                    CEO
# 15               NaN                        NaN                   NaN
# 16               NaN                        NaN                   NaN
#
#          Salary  Unnamed: 4    Names (Women)                     Company  \
# 0   243876539.0         NaN       Safra Catz                      Oracle
# 1   199718200.0         NaN       Ruth Porat                   Alphabet
# 2    98012344.0         NaN      Meg Whitman  Hewlett Packard Enterprise
# 3    83312974.0         NaN    Ginni Rometty                         IBM
# 4    68594646.0         NaN    Marissa Mayer                       Yahoo
# 5    61810000.0         NaN      Indra Nooyi                     Pepsico
# 6    47248312.0         NaN  Sheryl Sandberg                    Facebook
# 7    41272207.0         NaN  Angela Ahrendts                       Apple
# 8    40988618.0         NaN       Mary Barra              General Motors
# 9    40832279.0         NaN  Phebe Novakovic            General Dynamics
# 10   37510388.0         NaN  Marillyn Hewson             Lockheed Martin
# 11   37192354.0         NaN      Mary Erdoes              JPMorgan Chase
# 12   35760008.0         NaN     Gillian Tans                 Booking.com
# 13   35609644.0         NaN  Irene Rosenfeld      Mondelez International
# 14   35336616.0         NaN      Jane Elfers             Childrens Place
# 15          NaN         NaN              NaN                         NaN
# 16          NaN         NaN              NaN                         NaN
#
#                   Title.1    Salary.1  Unnamed: 9  Differency in Pay
# 0                     CEO  40729965.0         NaN          203146574
# 1                     CFO  39074129.0         NaN          160644071
# 2                     CEO  32935138.0         NaN           65077206
# 3                     CEO  32307434.0         NaN           51005540
# 4                     CEO  27410159.0         NaN           41184487
# 5                     CEO  25168597.0         NaN           36641403
# 6                     COO  24549457.0         NaN           22698855
# 7       Senior VP, Retail  22902892.0         NaN           18369315
# 8                     CEO  22400282.0         NaN           18588336
# 9                     CEO  21202838.0         NaN           19629441
# 10                    CEO  19422118.0         NaN           18088270
# 11  CEO, Asset Management  18400000.0         NaN           18792354
# 12                    CEO  17103279.0         NaN           18656729
# 13                    CEO  15840326.0         NaN           19769318
# 14                    CEO  15691170.0         NaN           19645446
# 15                    NaN         NaN         NaN                  0
# 16                    NaN         NaN         NaN                  0

# %%
execs.head()
# Out:
#        Names (Men)                Company                  Title       Salary  \
# 0        Marc Lore                 Walmart  CEO, U.S. E-Commerce  243876539.0
# 1    Sundar Pichai                  Google                   CEO  199718200.0
# 2  Thomas Rutledge  Charter Communications                   CEO   98012344.0
# 3    John Weinberg               Evercore     Executive Chairman   83312974.0
# 4   Leslie Moonves                    CBS                    CEO   68594646.0
#
#    Unnamed: 4  Names (Women)                     Company Title.1    Salary.1  \
# 0         NaN     Safra Catz                      Oracle     CEO  40729965.0
# 1         NaN     Ruth Porat                   Alphabet      CFO  39074129.0
# 2         NaN    Meg Whitman  Hewlett Packard Enterprise     CEO  32935138.0
# 3         NaN  Ginni Rometty                         IBM     CEO  32307434.0
# 4         NaN  Marissa Mayer                       Yahoo     CEO  27410159.0
#
#    Unnamed: 9  Differency in Pay
# 0         NaN          203146574
# 1         NaN          160644071
# 2         NaN           65077206
# 3         NaN           51005540
# 4         NaN           41184487

# %%
execs.tail()
# Out:
#        Names (Men)                   Company                Title      Salary  \
# 12   Thomas Kurian                     Oracle  President, Product  35760008.0
# 13    Andrew Jassy                     Amazon   CEO, Web Services  35609644.0
# 14  Jon Feltheimer  Lions Gate Entertainment                  CEO  35336616.0
# 15             NaN                        NaN                 NaN         NaN
# 16             NaN                        NaN                 NaN         NaN
#
#     Unnamed: 4    Names (Women)                 Company Title.1    Salary.1  \
# 12         NaN     Gillian Tans             Booking.com     CEO  17103279.0
# 13         NaN  Irene Rosenfeld  Mondelez International     CEO  15840326.0
# 14         NaN      Jane Elfers         Childrens Place     CEO  15691170.0
# 15         NaN              NaN                     NaN     NaN         NaN
# 16         NaN              NaN                     NaN     NaN         NaN
#
#     Unnamed: 9  Differency in Pay
# 12         NaN           18656729
# 13         NaN           19769318
# 14         NaN           19645446
# 15         NaN                  0
# 16         NaN                  0

# %% [markdown]
# ##### Run descriptive statistics on the file. Try using the following methods: shape, describe(), and info()

# %%
execs.shape
# Out:
# (17, 11)

# %%
execs.describe()
# Out:
#              Salary  Unnamed: 4      Salary.1  Unnamed: 9  Differency in Pay
# count  1.500000e+01         0.0  1.500000e+01         0.0       1.700000e+01
# mean   7.380501e+07         NaN  2.500919e+07         NaN       4.305514e+07
# std    6.358209e+07         NaN  8.022632e+06         NaN       5.524120e+07
# min    3.533662e+07         NaN  1.569117e+07         NaN       0.000000e+00
# 25%    3.735137e+07         NaN  1.891106e+07         NaN       1.858834e+07
# 50%    4.127221e+07         NaN  2.290289e+07         NaN       1.964545e+07
# 75%    7.595381e+07         NaN  2.985880e+07         NaN       4.118449e+07
# max    2.438765e+08         NaN  4.072996e+07         NaN       2.031466e+08

# %%
execs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 11 columns):
# Names (Men)          15 non-null object
# Company              15 non-null object
# Title                15 non-null object
# Salary               15 non-null float64
# Unnamed: 4           0 non-null float64
# Names (Women)        15 non-null object
# Company              15 non-null object
# Title.1              15 non-null object
# Salary.1             15 non-null float64
# Unnamed: 9           0 non-null float64
# Differency in Pay    17 non-null int64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 1.5+ KB

# %% [markdown]
# ##### Are there any columns with NaN values that can be dropped? Drop them with drop(columns = [])

# %%
# Remember to use one of the following to keep the changes in place:
# 'inplace = True' OR reassign the dataframe to a variable

# %%
execs.drop(columns=['Unnamed: 4', 'Unnamed: 9'], inplace= True)

# %% [markdown]
# ##### Check your work - call the DataFrame and check if the columns were dropped. Can anything else be dropped?

# %%
execs
# Out:
#          Names (Men)                   Company                  Title  \
# 0          Marc Lore                    Walmart  CEO, U.S. E-Commerce
# 1      Sundar Pichai                     Google                   CEO
# 2    Thomas Rutledge     Charter Communications                   CEO
# 3      John Weinberg                  Evercore     Executive Chairman
# 4     Leslie Moonves                       CBS                    CEO
# 5   Dean Metropoulos             Hostess Brands    Executive Chairman
# 6       John Bickham     Charter Communications                   COO
# 7   Lawrence Ellison                     Oracle                   CTO
# 8           Bob Iger                     Disney                   CEO
# 9          Mark Hurd                     Oracle                   CEO
# 10     Stephen Burke               NBCUniversal                   CEO
# 11      David Zaslav   Discovery Communications                   CEO
# 12     Thomas Kurian                     Oracle    President, Product
# 13      Andrew Jassy                     Amazon     CEO, Web Services
# 14    Jon Feltheimer  Lions Gate Entertainment                    CEO
# 15               NaN                        NaN                   NaN
# 16               NaN                        NaN                   NaN
#
#          Salary    Names (Women)                     Company  \
# 0   243876539.0       Safra Catz                      Oracle
# 1   199718200.0       Ruth Porat                   Alphabet
# 2    98012344.0      Meg Whitman  Hewlett Packard Enterprise
# 3    83312974.0    Ginni Rometty                         IBM
# 4    68594646.0    Marissa Mayer                       Yahoo
# 5    61810000.0      Indra Nooyi                     Pepsico
# 6    47248312.0  Sheryl Sandberg                    Facebook
# 7    41272207.0  Angela Ahrendts                       Apple
# 8    40988618.0       Mary Barra              General Motors
# 9    40832279.0  Phebe Novakovic            General Dynamics
# 10   37510388.0  Marillyn Hewson             Lockheed Martin
# 11   37192354.0      Mary Erdoes              JPMorgan Chase
# 12   35760008.0     Gillian Tans                 Booking.com
# 13   35609644.0  Irene Rosenfeld      Mondelez International
# 14   35336616.0      Jane Elfers             Childrens Place
# 15          NaN              NaN                         NaN
# 16          NaN              NaN                         NaN
#
#                   Title.1    Salary.1  Differency in Pay
# 0                     CEO  40729965.0          203146574
# 1                     CFO  39074129.0          160644071
# 2                     CEO  32935138.0           65077206
# 3                     CEO  32307434.0           51005540
# 4                     CEO  27410159.0           41184487
# 5                     CEO  25168597.0           36641403
# 6                     COO  24549457.0           22698855
# 7       Senior VP, Retail  22902892.0           18369315
# 8                     CEO  22400282.0           18588336
# 9                     CEO  21202838.0           19629441
# 10                    CEO  19422118.0           18088270
# 11  CEO, Asset Management  18400000.0           18792354
# 12                    CEO  17103279.0           18656729
# 13                    CEO  15840326.0           19769318
# 14                    CEO  15691170.0           19645446
# 15                    NaN         NaN                  0
# 16                    NaN         NaN                  0

# %% [markdown]
# ##### Try dropping the last two rows because they contain NaN values. Use drop(index = []).

# %%
execs.drop(index= [15,16], inplace = True)

# %% [markdown]
# ##### Call the DataFrame, again, to check your work

# %%
execs
# Out:
#          Names (Men)                   Company                  Title  \
# 0          Marc Lore                    Walmart  CEO, U.S. E-Commerce
# 1      Sundar Pichai                     Google                   CEO
# 2    Thomas Rutledge     Charter Communications                   CEO
# 3      John Weinberg                  Evercore     Executive Chairman
# 4     Leslie Moonves                       CBS                    CEO
# 5   Dean Metropoulos             Hostess Brands    Executive Chairman
# 6       John Bickham     Charter Communications                   COO
# 7   Lawrence Ellison                     Oracle                   CTO
# 8           Bob Iger                     Disney                   CEO
# 9          Mark Hurd                     Oracle                   CEO
# 10     Stephen Burke               NBCUniversal                   CEO
# 11      David Zaslav   Discovery Communications                   CEO
# 12     Thomas Kurian                     Oracle    President, Product
# 13      Andrew Jassy                     Amazon     CEO, Web Services
# 14    Jon Feltheimer  Lions Gate Entertainment                    CEO
#
#          Salary    Names (Women)                     Company  \
# 0   243876539.0       Safra Catz                      Oracle
# 1   199718200.0       Ruth Porat                   Alphabet
# 2    98012344.0      Meg Whitman  Hewlett Packard Enterprise
# 3    83312974.0    Ginni Rometty                         IBM
# 4    68594646.0    Marissa Mayer                       Yahoo
# 5    61810000.0      Indra Nooyi                     Pepsico
# 6    47248312.0  Sheryl Sandberg                    Facebook
# 7    41272207.0  Angela Ahrendts                       Apple
# 8    40988618.0       Mary Barra              General Motors
# 9    40832279.0  Phebe Novakovic            General Dynamics
# 10   37510388.0  Marillyn Hewson             Lockheed Martin
# 11   37192354.0      Mary Erdoes              JPMorgan Chase
# 12   35760008.0     Gillian Tans                 Booking.com
# 13   35609644.0  Irene Rosenfeld      Mondelez International
# 14   35336616.0      Jane Elfers             Childrens Place
#
#                   Title.1    Salary.1  Differency in Pay
# 0                     CEO  40729965.0          203146574
# 1                     CFO  39074129.0          160644071
# 2                     CEO  32935138.0           65077206
# 3                     CEO  32307434.0           51005540
# 4                     CEO  27410159.0           41184487
# 5                     CEO  25168597.0           36641403
# 6                     COO  24549457.0           22698855
# 7       Senior VP, Retail  22902892.0           18369315
# 8                     CEO  22400282.0           18588336
# 9                     CEO  21202838.0           19629441
# 10                    CEO  19422118.0           18088270
# 11  CEO, Asset Management  18400000.0           18792354
# 12                    CEO  17103279.0           18656729
# 13                    CEO  15840326.0           19769318
# 14                    CEO  15691170.0           19645446

# %%
execs.head(2)
# Out:
#      Names (Men) Company                  Title       Salary Names (Women)  \
# 0      Marc Lore  Walmart  CEO, U.S. E-Commerce  243876539.0    Safra Catz
# 1  Sundar Pichai   Google                   CEO  199718200.0    Ruth Porat
#
#      Company Title.1    Salary.1  Differency in Pay
# 0     Oracle     CEO  40729965.0          203146574
# 1  Alphabet      CFO  39074129.0          160644071

# %% [markdown]
# ##### Index search for the salary column to find the highest paid male. Do the same for females. Save each to a variable.

# %%
hfexecs = execs['Salary.1'][0]

# %%
hmexecs = execs['Salary'][0]

# %% [markdown]
# ##### What is the mean salary of male executives? Mean salary of female executives? Save both the values in variables.

# %%
avgmale = execs['Salary'].mean()

# %%
avgfemale = execs['Salary.1'].mean()

# %% [markdown]
# ##### What is the difference between the highest paid male and the mean male salary? What about for females?

# %%
malehmdiff = hmexecs - avgmale

# %%
femalehmdiff = hfexecs - avgfemale

# %%
h

# %% [markdown]
# ##### Combine the two salary columns into one column using the append() method. Save this column to a variable. It should now be a series.

# %%
new_column = executives['Salary'].append(executives['Salary.1'])

# %% [markdown]
# ##### Check the what datatype your new variable holds. Just to be sure.

# %% [markdown]
# ##### Call the series. Does it have an oddly numbered index?

# %% [markdown]
# ##### Reset the index of the new series. Use reset_index() method and save the result to a new variable.

# %% [markdown]
# ##### Call the new result. Notice it has a new column named 'index'? Drop that column using drop(columns = []).

# %% [markdown]
# ##### Check what datatype the column is now.

# %% [markdown]
# ##### Rename the sole column to 'total salaries' using rename(columns = []).

# %% [markdown]
# ##### What is the mean of all the executive salaries?

# %% [markdown]
# ##### Search for salaries above $30,000,000

# %% [markdown]
# ##### Run summary statistics on the column with all the executive salaries? Use shape, and describe() methods.

# %% [markdown]
# ##### Search for salaries for all Oracle executives
